# %% [markdown]
# Unit 2 Demo

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi, num=100)
y = np.sin(5*x)

# %%
plt.figure()
plt.plot(x, y)
plt.ylim(-1.1, 1.1)
plt.xlabel("X")
plt.ylabel("Y")
plt.savefig("demo.png", facecolor='b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
